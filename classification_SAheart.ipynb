# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib notebook

# %%
df = pd.read_csv("E:\projects\data mining\classification project\SA heart\SAheart.csv", sep=",", decimal=".")

# %%
df.head()
# Out:
#    row.names    sbp  tobacco   ldl  adiposity  famhist  typea  obesity  \
# 0          1  160.0    12.00  5.73      23.11  Present     49    25.30
# 1          2  144.0     0.01  4.41      28.61   Absent     55    28.87
# 2          3  118.0     0.08  3.48      32.28  Present     52    29.14
# 3          4  170.0     7.50  6.41      38.03  Present     51    31.99
# 4          5  134.0    13.60  3.50      27.78  Present     60    25.99
#
#    alcohol   age  chd
# 0    97.20  52.0  1.0
# 1     2.06  63.0  NaN
# 2     3.81  46.0  0.0
# 3    24.26  58.0  1.0
# 4    57.34  49.0  1.0

# %%
df.shape
# Out:
# (462, 11)

# %%
df.describe()
# Out:
#         row.names         sbp     tobacco         ldl   adiposity       typea  \
# count  462.000000  459.000000  462.000000  462.000000  462.000000  462.000000
# mean   231.935065  138.254902    3.635649    4.740325   25.406732   53.103896
# std    133.938585   20.431223    4.593024    2.070909    7.780699    9.817534
# min      1.000000  101.000000    0.000000    0.980000    6.740000   13.000000
# 25%    116.250000  124.000000    0.052500    3.282500   19.775000   47.000000
# 50%    231.500000  134.000000    2.000000    4.340000   26.115000   53.000000
# 75%    347.750000  148.000000    5.500000    5.790000   31.227500   60.000000
# max    463.000000  218.000000   31.200000   15.330000   42.490000   78.000000
#
#           obesity     alcohol         age         chd
# count  462.000000  462.000000  461.000000  456.000000
# mean    26.044113   17.044394   43.457701    0.344298
# std      4.213680   24.481059   35.206300    0.475661
# ...

# %%
df.isnull().sum()
# Out:
# row.names    0
# sbp          3
# tobacco      0
# ldl          0
# adiposity    0
# famhist      7
# typea        0
# obesity      0
# alcohol      0
# age          1
# chd          6
# dtype: int64

# %%
#dropna(self, axis=0, how="any", thresh=None, subset=None, inplace=False)
df = pd.DataFrame(df)
#df.droppna()

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# row.names    0
# sbp          0
# tobacco      0
# ldl          0
# adiposity    0
# famhist      0
# typea        0
# obesity      0
# alcohol      0
# age          0
# chd          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 447 entries, 0 to 461
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   row.names  447 non-null    int64
#  1   sbp        447 non-null    float64
#  2   tobacco    447 non-null    float64
#  3   ldl        447 non-null    float64
#  4   adiposity  447 non-null    float64
#  5   famhist    447 non-null    object
#  6   typea      447 non-null    int64
#  7   obesity    447 non-null    float64
#  8   alcohol    447 non-null    float64
#  9   age        447 non-null    float64
#  10  chd        447 non-null    float64
# dtypes: float64(8), int64(2), object(1)
# memory usage: 41.9+ KB

# %%
df["chd"].unique()
# Out:
# array([1., 0.])

# %%
df['famhist'].unique()
# Out:
# array(['Present', 'Absent'], dtype=object)

# %%
df['chd'].value_counts()
# Out:
# 0.0    295
# 1.0    152
# Name: chd, dtype: int64

# %%
sns.barplot(df["age"],df["chd"])
# Out:
# C:\Users\ali\Anaconda3\envs\tensorflow\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age', ylabel='chd'>

# %%
df.plot(x='age',y='obesity',kind='scatter',figsize =(10,5))
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <AxesSubplot:xlabel='age', ylabel='obesity'>

# %%
df.plot(x='age',y='tobacco',kind='scatter',figsize =(10,5))
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <AxesSubplot:xlabel='age', ylabel='tobacco'>

# %%
df.plot(x='age',y='alcohol',kind='scatter',figsize =(10,5))
# Out:
# <AxesSubplot:xlabel='age', ylabel='alcohol'>

# %%
#######################################
df.plot(kind = 'hist',figsize =(10,5))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
color = dict(boxes='DarkGreen', whiskers='DarkOrange',medians='DarkBlue', caps='Gray')

df.plot(kind='box',figsize=(10,6),color=color,ylim=[-10,90])
# Out:
# <AxesSubplot:>

# %%
# Feature Scaling, making categorical data precise 
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
df['famhist']=encoder.fit_transform(df['famhist'])
df['chd']=encoder.fit_transform(df['chd'])

# %%
df.head(5)
# Out:
#    row.names    sbp  tobacco   ldl  adiposity  famhist  typea  obesity  \
# 0          1  160.0    12.00  5.73      23.11        1     49    25.30
# 2          3  118.0     0.08  3.48      32.28        1     52    29.14
# 3          4  170.0     7.50  6.41      38.03        1     51    31.99
# 4          5  134.0    13.60  3.50      27.78        1     60    25.99
# 5          6  132.0     6.20  6.47      36.21        1     62    30.77
#
#    alcohol   age  chd
# 0    97.20  52.0    1
# 2     3.81  46.0    0
# 3    24.26  58.0    1
# 4    57.34  49.0    1
# 5    14.14  45.0    0

# %%
df['famhist'].value_counts()
# Out:
# 0    262
# 1    185
# Name: famhist, dtype: int64

# %%
pd.crosstab(index = df['famhist'], columns = df["chd"])
# Out:
# chd        0   1
# famhist
# 0        200  62
# 1         95  90

# %%
##################
sns.pairplot(df, hue="chd", size=2.5)
# Out:
# C:\Users\ali\Anaconda3\envs\tensorflow\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# <img src="data:image/png;base64,..." width="1705.4999491721408">

# %%
grid = sns.FacetGrid(df, col='chd', row='famhist', size=2.2, aspect=1.6)
grid.map(plt.hist, 'obesity', alpha=.5)
grid.add_legend();
# Out:
# C:\Users\ali\Anaconda3\envs\tensorflow\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
grid = sns.FacetGrid(df, col='chd', row='famhist', size=2.2, aspect=1.6)
grid.map(plt.hist, 'tobacco', alpha=.5)
grid.add_legend();
# Out:
# C:\Users\ali\Anaconda3\envs\tensorflow\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
chd_no = df['chd'].value_counts()[0]
chd_yes = df['chd'].value_counts()[1]
np.arange(2)
plt.bar([0,1], [chd_no, chd_yes], color = ["red", "blue"])
plt.xticks([0,1], ["No","Yes"])
# Out:
# ([<matplotlib.axis.XTick at 0x90c0ff59a0>,
# ...
#  [Text(0, 0, 'No'), Text(1, 0, 'Yes')])

# %%
#sns.countplot(df["famhist"])

# %%
sns.countplot(df["chd"])
# Out:
# C:\Users\ali\Anaconda3\envs\tensorflow\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='chd', ylabel='count'>

# %%
df2=df.drop("row.names", axis=1, inplace=True)
df.head()
# Out:
#      sbp  tobacco   ldl  adiposity  famhist  typea  obesity  alcohol   age  \
# 0  160.0    12.00  5.73      23.11        1     49    25.30    97.20  52.0
# 2  118.0     0.08  3.48      32.28        1     52    29.14     3.81  46.0
# 3  170.0     7.50  6.41      38.03        1     51    31.99    24.26  58.0
# 4  134.0    13.60  3.50      27.78        1     60    25.99    57.34  49.0
# 5  132.0     6.20  6.47      36.21        1     62    30.77    14.14  45.0
#
#    chd
# 0    1
# 2    0
# 3    1
# 4    1
# 5    0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 447 entries, 0 to 461
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   sbp        447 non-null    float64
#  1   tobacco    447 non-null    float64
#  2   ldl        447 non-null    float64
#  3   adiposity  447 non-null    float64
#  4   famhist    447 non-null    int32
#  5   typea      447 non-null    int64
#  6   obesity    447 non-null    float64
#  7   alcohol    447 non-null    float64
#  8   age        447 non-null    float64
#  9   chd        447 non-null    int64
# dtypes: float64(7), int32(1), int64(2)
# memory usage: 52.8 KB

# %%
# Out:
# C:\Users\ali\Anaconda3\envs\tensorflow\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='famhist', ylabel='count'>

# %%
sns.countplot(df.famhist)
# Out:
# C:\Users\ali\Anaconda3\envs\tensorflow\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='famhist', ylabel='count'>

# %%
df['age'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#sns.barplot(df,df["chd"])

# %%
sns.heatmap(df.corr())
#
#
#There are some correlations betwen some numeric features:

#adiposity and obesity
#adiposity and age
#tobaco and age
# Out:
# <AxesSubplot:>

# %%
df_sec =df

# %%
df_sec.head()
# Out:
#      sbp  tobacco   ldl  adiposity  famhist  typea  obesity  alcohol   age  \
# 0  160.0    12.00  5.73      23.11        1     49    25.30    97.20  52.0
# 2  118.0     0.08  3.48      32.28        1     52    29.14     3.81  46.0
# 3  170.0     7.50  6.41      38.03        1     51    31.99    24.26  58.0
# 4  134.0    13.60  3.50      27.78        1     60    25.99    57.34  49.0
# 5  132.0     6.20  6.47      36.21        1     62    30.77    14.14  45.0
#
#    chd
# 0    1
# 2    0
# 3    1
# 4    1
# 5    0

# %%
target= df["chd"]
print(target)
# Out:
# 0      1
# 2      0
# 3      1
# 4      1
# 5      0
#       ..
# 457    0
# 458    1
# 459    0
# 460    0
# 461    1
# Name: chd, Length: 447, dtype: int64

# %%
#df_test=df.drop(df['chd'],axis=1)
df.drop("chd", axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 447 entries, 0 to 461
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   sbp        447 non-null    float64
#  1   tobacco    447 non-null    float64
#  2   ldl        447 non-null    float64
#  3   adiposity  447 non-null    float64
#  4   famhist    447 non-null    int32
#  5   typea      447 non-null    int64
#  6   obesity    447 non-null    float64
#  7   alcohol    447 non-null    float64
#  8   age        447 non-null    float64
# dtypes: float64(7), int32(1), int64(1)
# memory usage: 33.2 KB

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df,target,test_size=0.2)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_clf = KNeighborsClassifier()
knn_clf.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred_knn = knn_clf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

knn_result = accuracy_score(y_test,y_pred_knn)
knn_result
# Out:
# 0.6333333333333333

# %%
from sklearn.preprocessing import StandardScaler

# %%
trans = StandardScaler()
df = trans.fit_transform(df)

# %%
#df.head()

# %%
from pandas import DataFrame

df = DataFrame(df)

df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  1.084510  1.825898  0.482693 -0.295397  1.190049 -0.433483 -0.179513
# 1 -0.995861 -0.779181 -0.605802  0.878410  1.190049 -0.126242  0.730043
# 2  1.579836  0.842437  0.811661  1.614440  1.190049 -0.228655  1.405105
# 3 -0.203339  2.175573 -0.596126  0.302387  1.190049  0.693068 -0.016077
# 4 -0.302404  0.558326  0.840688  1.381470  1.190049  0.897896  1.116131
#
#           7         8
# 0  3.259126  0.256627
# 1 -0.537430  0.085372
# 2  0.293918  0.427883
# 3  1.638709  0.171000
# 4 -0.117487  0.056830

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df,target,test_size=0.3)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_clf = KNeighborsClassifier()
knn_clf.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred_knn = knn_clf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

knn_result = accuracy_score(y_test,y_pred_knn)
knn_result
# Out:
# 0.7111111111111111

# %%
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  1.084510  1.825898  0.482693 -0.295397  1.190049 -0.433483 -0.179513
# 1 -0.995861 -0.779181 -0.605802  0.878410  1.190049 -0.126242  0.730043
# 2  1.579836  0.842437  0.811661  1.614440  1.190049 -0.228655  1.405105
# 3 -0.203339  2.175573 -0.596126  0.302387  1.190049  0.693068 -0.016077
# 4 -0.302404  0.558326  0.840688  1.381470  1.190049  0.897896  1.116131
#
#           7         8
# 0  3.259126  0.256627
# 1 -0.537430  0.085372
# 2  0.293918  0.427883
# 3  1.638709  0.171000
# 4 -0.117487  0.056830

# %%
# creating a dataframe with only numeric attributes of binary class dataset and encoded label attribute 
#numeric_bin = bin_data[numeric_col]
#numeric_bin['intrusion'] = bin_data['intrusion']
# finding the attributes which have more than 0.5 correlation with encoded attack label attribute 

corr= train_x.corr()
corr_y = abs(corr['label'])
highest_corr = corr_y[corr_y >0.5]
highest_corr.sort_values(ascending=True)

# %%
df3.drop("chd", axis=1, inplace=True)

# %%
df3.drop("alcohol", axis=1, inplace=True)

# %%
df.drop("chd", axis=1, inplace=True)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df,target,test_size=0.3)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df,target,test_size=0.3)

from sklearn.neighbors import KNeighborsClassifier
knn_clf = KNeighborsClassifier()
knn_clf.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
#upper_tri = cor_matrix.where(np.triu(np.ones(cor_matrix.shape),k=1).astype(np.bool))
#print(upper_tri)

# %%
#to_drop = [column for column in upper_tri.columns if any(upper_tri[column] > 0.5)]
#print(); print(to_drop)

# %%
#df3.drop("obesity", axis=1, inplace=True)

# %%
#from sklearn.model_selection import train_test_split

#X_train2, X_test2, y_train2, y_test2 = train_test_split(df3,target,test_size=0.3)

#from sklearn.neighbors import KNeighborsClassifier
#knn_clf2 = KNeighborsClassifier()
#knn_clf2.fit(X_train2,y_train2)

#y_pred_knn2 = knn_clf2.predict(X_test2)
#from sklearn.metrics import accuracy_score

#knn_result2 = accuracy_score(y_test2,y_pred_knn2)
#knn_result2

# %%
# selecting categorical data attributes
#clounms_after_corr = ['count','srv_serror_rate','dst_host_serror_rate','dst_host_serror_rate','dst_host_srv_serror_rate','logged_in',
#'dst_host_same_srv_rate','dst_host_srv_count','same_srv_rate']
# creating a dataframe with only categorical attributes
#categorical = train_x[clounms_after_corr]
#categorical.head()

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.pipeline import Pipeline
knn_pipe = Pipeline([('mms', StandardScaler()),
                     ('knn', KNeighborsClassifier())])
params = [{'knn__n_neighbors': [2,3,4, 5,6, 7,8, 9,10,15,16,17,18,19,20],
         'knn__weights': ['uniform', 'distance'],
         'knn__leaf_size': [15, 20]}]
gs_knn = GridSearchCV(knn_pipe,
                      param_grid=params,
                      scoring='accuracy',
                      cv=5)
gs_knn.fit(X_train, y_train)
gs_knn.best_params_
# Out:
# {'knn__leaf_size': 15, 'knn__n_neighbors': 18, 'knn__weights': 'uniform'}

# %% [markdown]
# ##  result after hyper parameter tuning

# %%
y_pred_knn2 = gs_knn.predict(X_test)
from sklearn.metrics import accuracy_score
knn_result2 = accuracy_score(y_test,y_pred_knn2)
knn_result2
# Out:
# 0.7703703703703704
